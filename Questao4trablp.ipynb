# %% [markdown]
# <a href="https://colab.research.google.com/github/josuelibarbosa/Aula-1/blob/main/Questao4trablp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mensagem de boas-vindas com o nome
print('-Bem-vindo(a) ao sistema de gerenciamento de livros!-')
print('------ Desenvolvido por Josueli da Mata Barbosa------')

# Lista vazia para armazenar os livros e id global
lista_livro = []
id_global = 0

# Função para cadastrar um livro
def cadastrar_livro(id):
  print('\n-----------------------------------------------------')
  print('---------------- Cadastro de Livro ------------------')
  print('-----------------------------------------------------')
  print(f'ID do livro: {id}')  # Exibe o ID do livro
  nome = input('Digite o nome do livro: ')
  autor = input('Digite o autor do livro: ')
  editora = input('Digite a editora do livro: ')
  livro = {'id': id, 'nome': nome, 'autor': autor, 'editora': editora}
  lista_livro.append(livro)
  print('----------- Livro cadastrado com sucesso! -----------')
  print('-----------------------------------------------------\n')

# Função para consultar livros
def consultar_livro():
  while True:
    print('\n-----------------------------------------------------')
    print('---------------- Consulta de Livro ------------------')
    print('-----------------------------------------------------')
    print('Opções de consulta: \n')
    print('1. Consultar Todos')
    print('2. Consultar por Id')
    print('3. Consultar por Autor')
    print('4. Retornar ao menu principal')
    opcao = input('Digite a opção desejada: ')

    if opcao == '1':
      if not lista_livro:
        print('---------------- Nenhum livro cadastrado.----------------\n')
      else:
        print('\n---------------- Lista de Livros ------------------')
        for livro in lista_livro:
          print(f'ID: {livro["id"]}, Nome: {livro["nome"]}, Autor: {livro["autor"]}, Editora: {livro["editora"]}\n')
    elif opcao == '2':
      id_consulta = int(input('Digite o ID do livro: '))
      livro_encontrado = None
      for livro in lista_livro:
        if livro['id'] == id_consulta:
          livro_encontrado = livro
          break
      if livro_encontrado:
        print('\n---------------- Livro Encontrado ------------------')
        print(f'ID: {livro_encontrado["id"]}, Nome: {livro_encontrado["nome"]}, Autor: {livro_encontrado["autor"]}, Editora: {livro_encontrado["editora"]}\n')
      else:
        print('---------------- Livro não encontrado.----------------\n')
    elif opcao == '3':
      autor_consulta = input('Digite o autor do livro: ')
      livros_encontrados = []
      for livro in lista_livro:
        if livro['autor'] == autor_consulta:
          livros_encontrados.append(livro)
      if livros_encontrados:
        print(f'\n---------------- Livros de {autor_consulta} ----------------')
        for livro in livros_encontrados:
          print(f'ID: {livro["id"]}, Nome: {livro["nome"]}, Autor: {livro["autor"]}, Editora: {livro["editora"]}\n')
      else:
        print('----------------Nenhum livro encontrado para este autor.----------------\n')
    elif opcao == '4':
      break
    else:
      print('---------------- Opção inválida.----------------\n')

# Função para remover um livro
def remover_livro():
  print('\n-----------------------------------------------------')
  print('---------------- Remoção de Livro -------------------')
  print('-----------------------------------------------------')
  id_remover = int(input('Digite o ID do livro a ser removido: '))
  for livro in lista_livro:
    if livro['id'] == id_remover:
      lista_livro.remove(livro)
      print('------------- Livro removido com sucesso!------------\n')
      return
  print('-------------------- ID inválido.--------------------\n')

# Menu principal
while True:
  print('-----------------------------------------------------')
  print('------------------ MENU PRINCIPAL--------------------')
  print('-----------------------------------------------------')
  print('Escolha a opção desejada:')
  print('1. Cadastrar Livro')
  print('2. Consultar Livro')
  print('3. Remover Livro')
  print('4. Encerrar Programa')
  opcao = input('Digite a opção desejada: ')

  if opcao == '1':
    id_global += 1
    cadastrar_livro(id_global)
  elif opcao == '2':
    consultar_livro()
  elif opcao == '3':
    remover_livro()
  elif opcao == '4':
    print('-----------------------------------------------------')
    print('---------------- Programa encerrado! ----------------')
    print('-----------------------------------------------------\n')
    break
  else:
    print('------------------ Opção inválida.-------------------')
# Out:
# -Bem-vindo(a) ao sistema de gerenciamento de livros!-
# ------ Desenvolvido por Josueli da Mata Barbosa------
# -----------------------------------------------------
# ------------------ MENU PRINCIPAL--------------------
# -----------------------------------------------------
# Escolha a opção desejada:
# 1. Cadastrar Livro
# 2. Consultar Livro
# 3. Remover Livro
# 4. Encerrar Programa
# Digite a opção desejada: 1
#
# -----------------------------------------------------
# ---------------- Cadastro de Livro ------------------
# -----------------------------------------------------
# ID do livro: 1
# Digite o nome do livro: Orgulho e preconceito
# Digite o autor do livro: Jane Austen
# Digite a editora do livro: Principis
# ----------- Livro cadastrado com sucesso! -----------
# -----------------------------------------------------
#
# -----------------------------------------------------
# ------------------ MENU PRINCIPAL--------------------
# ...
